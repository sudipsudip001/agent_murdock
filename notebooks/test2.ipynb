# %% [markdown]
# # Testing Agent with web search tool

# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

# %%
from app.pipeline.agent.graph import Graph

graph = Graph()
answer =  await graph.run("Is Cole Palmer selected for the world cup 2026?")
print(answer)

# %% [markdown]
# ### Output:
#
# {"answer": "Cole Palmer missed out on England's 2026 World Cup squad [1].", "citations": [{"src": "Thomas Tuchel gives his reasons for leaving the likes of Cole ...", "page": 1}]}

# %%
from app.pipeline.agent.graph import Graph

graph = Graph()
answer = await graph.run("What is Gharbari referred to?")
print(answer)

# %% [markdown]
# ### Output:
#
# {"answer": "Gharbari, also referred to as \"House and premises,\" encompasses a dwelling house along with its appurtenant land. This term also includes structures such as cattle sheds, grain stores, wells, ponds, garages, stables, fruit gardens, bamboo bushes, grass fields, and sites for sports or recreation, as well as other similar land uses, regardless of whether they are directly adjoined to the house [1].", "citations": [{"src": "../PDF_DOCS/LandAct1964.pdf", "page": 5}]}

# %%
from app.pipeline.agent.graph import Graph

graph = Graph()
answer =  await graph.run("What is the best trekking destination in Nepal?")
print(answer)

# %% [markdown]
# ### Output:
#
# {"answer": "Nepal offers a variety of popular trekking destinations, each with distinct features. The **Kanchanjunga Trek** is a challenging and remote option, providing a less commercialized experience with views of high peaks and opportunities to see rare wildlife like Red Pandas and Snow Leopards [1]. For those interested in Buddhist monasteries and cultural immersion, the **Upper Mustang Trek** is a moderate choice that includes horse-riding to Lo Manthang and exposure to Tibetan Buddhist culture [1]. The **Annapurna Circuit Trek** is renowned for its diverse landscapes, from lush forests to arid deserts, and features Tilicho Lake, one of the world's highest lakes [5]. The **Everest Base Camp Trek (EBC)** is a blend of adventure, culture, and natural beauty, offering experiences in traditional Sherpa villages and stunning mountain views [7]. Lastly, the **Langtang Valley Trek** is a shorter, delightful journey known for its beautiful mountain vistas and unique local culture, and is considered a reliable trek suitable for families [4, 6, 8]. The optimal time for trekking in Nepal is typically during autumn (September-November) and spring (March-May) due to stable weather, clear skies, and moderate temperatures [2, 5, 6].", "citations": [{"src": "SearchWeb_response", "page": 1}, {"src": "SearchWeb_response", "page": 2}, {"src": "SearchWeb_response", "page": 5}, {"src": "SearchWeb_response", "page": 6}, {"src": "SearchWeb_response", "page": 7}, {"src": "SearchWeb_response", "page": 8}]}

# %%
from app.pipeline.agent.graph import Graph

graph = Graph()
answer = await graph.run("What is the meaning of harbor in the crime department?")
print(answer)

# %% [markdown]
# ### Output:
#
# {"answer": "In the crime department, \"harbor\" means supplying any person with food, drink, shelter, money, in-kind, clothes, arms, ammunition, or means of transport, or helping or otherwise assisting any person to evade apprehension [1]. It is prohibited to knowingly harbor an offender with the intent to prevent them from being apprehended or to save them from a lawful sentence [2].", "citations": [{"src": "../PDF_DOCS/NP_National Penal Code Act_EN.pdf", "page": 4}, {"src": "../PDF_DOCS/NP_National Penal Code Act_EN.pdf", "page": 60}]}
